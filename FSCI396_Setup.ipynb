# %% [markdown]
# # FSCI 396: Setting Up Packages
#
# ------------------
# Run the below block once to install all necessary packages.

# %%
pip install numpy pandas matplotlib seaborn openpyxl statsmodels semopy graphviz factor-analyzer
